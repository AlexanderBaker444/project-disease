# %%
import pandas as pd
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
current=Path.cwd()

# %%
current
# Out:
# WindowsPath('C:/Users/603766/Desktop/general_assembly/projects')

# %%
data_path=Path.joinpath(current,'data')

# %%
data_path
# Out:
# WindowsPath('C:/Users/603766/Desktop/general_assembly/projects/data')

# %%
os.listdir(data_path)
# Out:
# ['dengue_features_test.csv',
#  'dengue_features_train.csv',
#  'dengue_labels_train.csv']

# %%
full_path_X=Path.joinpath(data_path,'dengue_labels_train.csv')
full_path_Y=Path.joinpath(data_path,'dengue_features_train.csv')

# %%
df_X=pd.read_csv(full_path_X)
df_Y=pd.read_csv(full_path_Y)

# %%
df_X.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
df_Y.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
full_set=pd.merge(df_X,df_Y)

# %%
full_set.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'total_cases', 'week_start_date',
#        'ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm',
#        'reanalysis_air_temp_k', 'reanalysis_avg_temp_k',
#        'reanalysis_dew_point_temp_k', 'reanalysis_max_air_temp_k',
#        'reanalysis_min_air_temp_k', 'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm'],
#       dtype='object')

# %%
full_set.dtypes
# Out:
# city                                      object
# year                                       int64
# weekofyear                                 int64
# total_cases                                int64
# week_start_date                           object
# ndvi_ne                                  float64
# ndvi_nw                                  float64
# ndvi_se                                  float64
# ndvi_sw                                  float64
# precipitation_amt_mm                     float64
# reanalysis_air_temp_k                    float64
# reanalysis_avg_temp_k                    float64
# reanalysis_dew_point_temp_k              float64
# reanalysis_max_air_temp_k                float64
# reanalysis_min_air_temp_k                float64
# reanalysis_precip_amt_kg_per_m2          float64
# reanalysis_relative_humidity_percent     float64
# reanalysis_sat_precip_amt_mm             float64
# reanalysis_specific_humidity_g_per_kg    float64
# ...

# %%
cc=full_set['city'].value_counts()

# %%
cc.plot(kind='bar')

# %%
plt.hist(full_set['total_cases'])
# Out:
# (array([1266.,  132.,   26.,   12.,    5.,    3.,    2.,    5.,    3.,
#            2.]),
#  array([  0. ,  46.1,  92.2, 138.3, 184.4, 230.5, 276.6, 322.7, 368.8,
#         414.9, 461. ]),
#  <a list of 10 Patch objects>)

# %%
full_set['total_cases']
# Out:
# 0        4
# 1        5
# 2        4
# 3        3
# 4        6
# 5        2
# 6        4
# 7        5
# 8       10
# 9        6
# 10       8
# 11       2
# 12       6
# 13      17
# 14      23
# 15      13
# 16      21
# 17      28
# 18      24
# 19      20
# 20      40
# 21      27
# 22      42
# 23      33
# 24      43
# 25      37
# 26      57
# 27      71
# 28      44
# 29      56
#         ..
# 1426     4
# 1427     4
# 1428     1
# 1429     0
# 1430     0
# 1431    10
# 1432     9
# 1433    17
# 1434    16
# 1435    11
# 1436    12
# 1437    19
# 1438    15
# 1439    12
# 1440    12
# 1441    16
# 1442     9
# 1443     4
# 1444     9
# 1445     6
# 1446     8
# 1447     4
# 1448     2
# 1449     7
# 1450     6
# 1451     5
# 1452     8
# 1453     1
# 1454     1
# 1455     4
# Name: total_cases, Length: 1456, dtype: int64

# %%
lgcases=np.log(full_set['total_cases']+1)
plt.hist(lgcases)
# Out:
# (array([100., 128., 196., 255., 287., 260., 140.,  56.,  19.,  15.]),
#  array([0.        , 0.61355649, 1.22711298, 1.84066947, 2.45422596,
#         3.06778245, 3.68133893, 4.29489542, 4.90845191, 5.5220084 ,
#         6.13556489]),
#  <a list of 10 Patch objects>)

# %%
full_set['log_cases']=lgcases

# %%
cm=full_set.corr()
cm
# Out:
#                                            year  weekofyear  total_cases  \
# year                                   1.000000   -0.071649    -0.306806
# weekofyear                            -0.071649    1.000000     0.216452
# total_cases                           -0.306806    0.216452     1.000000
# ndvi_ne                                0.223361    0.053548    -0.241376
# ndvi_nw                                0.144345    0.048759    -0.202235
# ndvi_se                                0.234234    0.121557    -0.168612
# ndvi_sw                                0.277759    0.068701    -0.196461
# precipitation_amt_mm                   0.205302    0.118037    -0.038740
# reanalysis_air_temp_k                 -0.140016    0.425753     0.264952
# reanalysis_avg_temp_k                  0.085043    0.463677     0.151637
# reanalysis_dew_point_temp_k            0.132273    0.348946     0.142531
# reanalysis_max_air_temp_k              0.480402    0.238078    -0.191345
# ...

# %%
plt.imshow(cm)

# %%
full_set.boxplot(column='log_cases',by='city')

# %%
full_set.plot(kind='scatter',x='station_avg_temp_c',y='station_precip_mm',c='station_diur_temp_rng_c',colormap='RdBu')

# %%
full_set['week_start_date']=pd.to_datetime(full_set['week_start_date'])

# %%
full_set.head()
# Out:
#   city  year  weekofyear  total_cases week_start_date   ndvi_ne   ndvi_nw  \
# 0   sj  1990          18            4      1990-04-30  0.122600  0.103725
# 1   sj  1990          19            5      1990-05-07  0.169900  0.142175
# 2   sj  1990          20            4      1990-05-14  0.032250  0.172967
# 3   sj  1990          21            3      1990-05-21  0.128633  0.245067
# 4   sj  1990          22            6      1990-05-28  0.196200  0.262200
#
#     ndvi_se   ndvi_sw  precipitation_amt_mm  ...  \
# 0  0.198483  0.177617                 12.42  ...
# 1  0.162357  0.155486                 22.82  ...
# 2  0.157200  0.170843                 34.54  ...
# 3  0.227557  0.235886                 15.36  ...
# 4  0.251200  0.247340                  7.52  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# ...

# %%
sns.lineplot(x='week_start_date',y='log_cases',data=full_set)

# %%
full_set.year
# Out:
# 0       1990
# 1       1990
# 2       1990
# 3       1990
# 4       1990
# 5       1990
# 6       1990
# 7       1990
# 8       1990
# 9       1990
# 10      1990
# 11      1990
# 12      1990
# 13      1990
# 14      1990
# 15      1990
# 16      1990
# 17      1990
# 18      1990
# 19      1990
# 20      1990
# 21      1990
# 22      1990
# 23      1990
# 24      1990
# 25      1990
# 26      1990
# 27      1990
# 28      1990
# 29      1990
#         ...
# 1426    2009
# 1427    2009
# 1428    2009
# 1429    2009
# 1430    2010
# 1431    2010
# 1432    2010
# 1433    2010
# 1434    2010
# 1435    2010
# 1436    2010
# 1437    2010
# 1438    2010
# 1439    2010
# 1440    2010
# 1441    2010
# 1442    2010
# 1443    2010
# 1444    2010
# 1445    2010
# 1446    2010
# 1447    2010
# 1448    2010
# 1449    2010
# 1450    2010
# 1451    2010
# 1452    2010
# 1453    2010
# 1454    2010
# 1455    2010
# Name: year, Length: 1456, dtype: int64

# %%
sns.lineplot(x='year',y='log_cases',data=full_set)

# %%
sns.pairplot(data=full_set,vars=['ndvi_se','ndvi_sw','ndvi_ne','ndvi_nw','log_cases'])
# Out:
# C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(data=full_set,vars=['reanalysis_sat_precip_amt_mm','reanalysis_dew_point_temp_k','reanalysis_air_temp_k','reanalysis_relative_humidity_percent','reanalysis_specific_humidity_g_per_kg','reanalysis_precip_amt_kg_per_m2','reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_avg_temp_k','reanalysis_tdtr_k','log_cases'])

# %%
#reanalysis_min_air_temp_k
#reanalysis_avg_air_temp_k
#reanalysis_max_air_temp_k
#kg_m2 in perciptation
#air temp and humdity are loosely correlated
#both contribute to number of cases
#percipataion and humidtity and temperature are correlated
# this can be condensed into one variable 

#turn percentage humidity into a metric to use
# low humidity, humid, and high humidity based on the percetages

# %%
cases_per_year=full_set.groupby('year')['log_cases'].mean()
cpy=pd.DataFrame(cases_per_year)

# %%
cpy.plot(kind='line')

# %%
full_set['humidity_level']='low_humidty'
full_set.loc[full_set['reanalysis_relative_humidity_percent'].between(77,86),'humidity_level']='med_humidity'
full_set.loc[full_set['reanalysis_relative_humidity_percent'].between(86,100),'humidity_level']='high_humidity'

# %%
cnts=full_set['humidity_level'].value_counts()

# %%
full_set['reanalysis_relative_humidity_percent'].describe()
# Out:
# count    1446.000000
# mean       82.161959
# std         7.153897
# min        57.787143
# 25%        77.177143
# 50%        80.301429
# 75%        86.357857
# max        98.610000
# Name: reanalysis_relative_humidity_percent, dtype: float64

# %%
full_set['station_avg_temp_c'].describe()
# Out:
# count    1413.000000
# mean       27.185783
# std         1.292347
# min        21.400000
# 25%        26.300000
# 50%        27.414286
# 75%        28.157143
# max        30.800000
# Name: station_avg_temp_c, dtype: float64

# %%
full_set['station_precip_mm'].describe()
# Out:
# count    1434.000000
# mean       39.326360
# std        47.455314
# min         0.000000
# 25%         8.700000
# 50%        23.850000
# 75%        53.900000
# max       543.300000
# Name: station_precip_mm, dtype: float64

# %%
cnts.plot(kind='bar')

# %%
hl_city=pd.crosstab(full_set['city'],full_set['humidity_level'])
hl_city
# Out:
# humidity_level  high_humidity  low_humidty  med_humidity
# city
# iq                        360           50           110
# sj                          6          306           624

# %%
hl_city.plot(kind='bar')

# %%
#avg temp 
#total_percip
full_set['temp_level']='low_temp'
full_set.loc[full_set['station_avg_temp_c'].between(26,28),'temp_level']='med_temp'
full_set.loc[full_set['station_avg_temp_c'].between(28,30),'temp_level']='high_temp'

# %%
full_set['humidity_level']='low_humidty'
full_set.loc[full_set['station_precip_mm'].between(26,53),'humidity_level']='med_humidity'
full_set.loc[full_set['station_precip_mm'].between(53,600),'humidity_level']='high_humidity'

# %%
full_set['temp_level'].value_counts()
# Out:
# med_temp     682
# high_temp    437
# low_temp     337
# Name: temp_level, dtype: int64

# %%
full_set['humidity_level'].value_counts()
# Out:
# low_humidty      777
# high_humidity    371
# med_humidity     308
# Name: humidity_level, dtype: int64

# %%
hum_temp=pd.crosstab(full_set['humidity_level'],full_set['temp_level'])
hum_temp
# Out:
# temp_level      high_temp  low_temp  med_temp
# humidity_level
# high_humidity          90        54       227
# low_humidty           251       222       304
# med_humidity           96        61       151

# %%
hum_temp.plot(kind='barh')

# %%
triple=full_set.groupby(['humidity_level','temp_level'])['city'].count()

# %%
triple.plot(kind='barh')

# %%
mylabels=full_set['city'].value_counts().index
mysizes=full_set['city'].value_counts().values

# %%
fig1, ax1= plt.subplots()
ax1.pie(mysizes, labels=mylabels, autopct='%1.1f%%')
ax1.axis('equal')
plt.show;

# %%
mylabels=full_set['humidity_level'].value_counts().index
mysizes=full_set['humidity_level'].value_counts().values

# %%
fig1, ax1= plt.subplots()
ax1.pie(mysizes, labels=mylabels, autopct='%1.1f%%')
ax1.axis('equal')
plt.show;

# %%
sns.lineplot(x='week_start_date',y='station_avg_temp_c',data=full_set)

# %%
sns.lineplot(x='week_start_date',y='station_precip_mm',data=full_set)

# %%
sns.lineplot(x='week_start_date',y='reanalysis_relative_humidity_percent',data=full_set)
